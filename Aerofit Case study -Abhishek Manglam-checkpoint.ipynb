# %% [markdown]
# About Aerofit
#
# Aerofit is a leading brand in the field of fitness equipment. Aerofit provides a product range including machines such as treadmills, exercise bikes, gym equipment, and fitness accessories to cater to the needs of all categories of people.
#
#
# Business Problem
#
# The market research team at AeroFit wants to identify the characteristics of the target audience for each type of treadmill offered by the company, to provide a better recommendation of the treadmills to the new customers. The team decides to investigate whether there are differences across the product with respect to customer characteristics.
#
# Perform descriptive analytics to create a customer profile for each AeroFit treadmill product by developing appropriate tables and charts.
# For each AeroFit treadmill product, construct two-way contingency tables and compute all conditional and marginal probabilities along with their insights/impact on the business.

# %%
#Import the libraries:

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read the aerofit data:
df = pd.read_csv("aerofit_treadmill.csv")
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
#Checking missing values:
df.isnull().sum()/len(df)*100
# Out:
# Product          0.0
# Age              0.0
# Gender           0.0
# Education        0.0
# MaritalStatus    0.0
# Usage            0.0
# Fitness          0.0
# Income           0.0
# Miles            0.0
# dtype: float64

# %%
#Checking the characteristics of the data:
df.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# Initial Observations:
#
#     1. There are no missing values in the data.
#
#     2. There are 3 unique products in the dataset. KP281 is the most sold product.
#
#     3. Although the difference between mean and median is not too significant but we do have some noticable differences in mean and median for age, income, and miles which suggests outliers in the data.
#
#     4. Minimum & Maximum age of the person is 18 & 50, mean is 28.79 and 75% of persons have age less than or equal to 33.        It suggest mostly young people buy these product.
#
#     5. Most of the people are having 16 years of education i.e. 75% of persons are having education <= 16 years.
#
#     6. Out of 180 data points, 104's gender is Male and rest are the female. Also, the partnered people are more likely to        buy the product than single.
#
#     7. Standard deviation for Income & Miles are on a little higher side suggests data is more spread out for these attributes.

# %% [markdown]
# Univariate Analysis:
#
#     We can explore the distribution of the data for the quantitative attributes using histplot.

# %%
fig, axis = plt.subplots(nrows=3, ncols=2, figsize=(18, 10))
fig.subplots_adjust(top=1.2)

sns.histplot(data=df, x="Age", kde=True, ax=axis[0,0])
sns.histplot(data=df, x="Education", kde=True, ax=axis[0,1])
sns.histplot(data=df, x="Fitness", kde=True, ax=axis[1,0])
sns.histplot(data=df, x="Income", kde=True, ax=axis[1,1])
sns.histplot(data=df, x="Miles", kde=True, ax=axis[2,0])
sns.histplot(data=df, x="Usage", kde=True, ax=axis[2,1])
plt.show()

# %% [markdown]
# From the histplot we can clearly see data is little right-skewed for income,age, and miles.
#
# Outliers detection using boxplot:

# %%
fig, axis = plt.subplots(nrows=3, ncols=2, figsize=(16, 10))
fig.subplots_adjust(top=1.2)

sns.boxplot(data=df, x="Age", orient='h', ax=axis[0,0])
sns.boxplot(data=df, x="Education", orient='h', ax=axis[0,1])
sns.boxplot(data=df, x="Fitness", orient='h', ax=axis[1,0])
sns.boxplot(data=df, x="Income", orient='h', ax=axis[1,1])
sns.boxplot(data=df, x="Miles", orient='h', ax=axis[2,0])
sns.boxplot(data=df, x="Usage", orient='h', ax=axis[2,1])
plt.show()

# %% [markdown]
# Obervation:
#
# Even from the boxplots below points are evident:
#
#     1. Age, Education, Fitness, and Usage are having very few outliers.
#     2. Income and Miles have more outliers.

# %% [markdown]
# Bivariate Analysis:

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(20, 12))
sns.countplot(data=df, x='Product', ax=axs[0,0])
sns.countplot(data=df, x='Gender', ax=axs[0,1])
sns.countplot(data=df, x='MaritalStatus', ax=axs[1,0])
sns.countplot(data=df, x='Age', ax=axs[1,1])


axs[0,0].set_title("Product - counts", pad=10, fontsize=14)
axs[0,1].set_title("Gender - counts", pad=10, fontsize=14)
axs[1,0].set_title("MaritalStatus - counts", pad=10, fontsize=14)
axs[1,1].set_title("Age - counts", pad=10, fontsize=14)
plt.show()

# %% [markdown]
# Insights:
#
#     KP281 is the most frequent product.
#     There are more males in the data than females.
#     More Partnered persons has bought the product.
#     More youth are likely to buy the product with aged 25 being the highest.
#
# Recommendation:
#
#     Aerofit needs to expand their hold for aged customers by launching fitness awareness program. The awareness program can be launched separately basis differnt categories like sometimes they can target aged customers, sometimes gender based and sometimes marital status. This way the customers will have more personal experience and will be more likely to buy the product if the program would be a general one catering to all class of the customers together.

# %%
fig, axis = plt.subplots(nrows=5, ncols=2, figsize=(16, 14))
fig.subplots_adjust(top=1.2)

sns.boxplot(data=df, x="Gender", y='Income', ax=axis[0,0])
sns.boxplot(data=df, x="Gender", y='Education', ax=axis[0,1])
sns.boxplot(data=df, x="Age", y='Income', ax=axis[1,0])
sns.boxplot(data=df, x="Education", y='Income', ax=axis[1,1])
sns.boxplot(data=df, x="Product", y='Age', ax=axis[2,0])
sns.boxplot(data=df, x="Product", y='Income', ax=axis[2,1])
sns.boxplot(data=df, x="MaritalStatus", y='Income', ax=axis[3,0])
sns.boxplot(data=df, x="Gender", y='Age', ax=axis[3,1])
sns.boxplot(data=df, x="MaritalStatus", y='Education', ax=axis[4,0])
sns.boxplot(data=df, x="Product", y='Fitness', ax=axis[4,1])
plt.show()

# %% [markdown]
# Insights:
#
#     1. Males income are higher than females. Also, there are more outliers for males.
#     2. Higher education likely to result in higher income.
#     3. There seems to be some correlation in the income with the increasing age.
#     4. The median age for all products are similar  which suggests age is not a dominant factor in deciding which product to buy.
#     5. More fit customers are more likely to buy KP781 product.
#     6. Customers with high income are more likely to buy KP781.
#     7. The median income difference for KP781 and KP481 is quite significant which suggests if one more product can be launched in between KP481 and KP781 then customer in the medium range can buy slightly higher range product.
#     8. Partnered customers have higher income and are more likely to buy the product. More number of outliers for partnered customers.
#     9. Average age for male and female buying the product is almost same. Still, we see the outliers for female only. Only few elderly women seems to have concern for their fitness and can buy the product.
#
#
# Recommendation:
#
#     1. As we can see males income are higher which can be the reason males are more likely to buy the product. And we see males have higher income than females. Aerofit can support program which promotes oppurtunities for women so that they can also earn more which can increase the womens chances of buying the product.
#     2.Aerofit can also support eduaction programmes or they themselves can advertise educated models to advertise their product to attract more customers.
#     3.Aerofit can select the aged outlier female and showcase her example to further attract the aged female customers.

# %% [markdown]
# Impact of gender and marital status on the product bought:

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
sns.countplot(data=df, x='Product', hue="Gender", ax=axs[0])
sns.countplot(data=df, x='Product', hue="MaritalStatus",ax=axs[1])

axs[0].set_title("Product Vs Gender", pad=10, fontsize=14)
axs[1].set_title("Product Vs MaritalStatus", pad=10, fontsize=14)

plt.show()

# %%
Insights:
    1. Very few females bought KP781.
    2. For other product categories not much differences between male and female buying the product.
    3. Partnered customers are more likely to buy the products.

# %%
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(25, 10))
sns.countplot(data=df, x='Product', hue="Age",edgecolor="0.10").set_title("Product Vs Age", fontsize=18)

plt.show()

# %% [markdown]
# Insights:
#
#     From the above countplot we can see the buying of product basis age. We can clearly see young customers are more likely to buy the product. Also, we have seen with higher income there is greater chance of buying KP781.So, young customers with higher income can go for KP781. The old customers with higher income are not very likely to go for higher end product.
#
# Recommendation:
#
#     Aged customers with very high income can be targeted for increase of the high end products by giving them some discounts or fitness awareness program.

# %% [markdown]
# Insight basis converting gender to numeric and checking the count for males and females for partnered customers:

# %%
dfnew=df.copy(deep=True)
dfnew['Gender'].replace({'Male':1, 'Female':0},inplace=True)
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(10, 4))
sns.countplot(data=dfnew, x='MaritalStatus', hue="Gender",edgecolor="0.10").set_title("MaritalStatus Vs Gender", fontsize=18)
# Out:
# Text(0.5, 1.0, 'MaritalStatus Vs Gender')

# %% [markdown]
# Insights:
#
#     There are more single male customers than single female.
#     There are more partnered male customers than partnered females. But, in case of partnered we can assume the product has been registered against any one of the partnered member. So, this can be reason for the higher count of males than females.
#
#  Recommendation:
#
#      We should try to capture in case of partnered if both male and female going to use the product or only one. This will give a more clear count of males and females and clearer insight for gender based analysis.

# %% [markdown]
# Insight basis custom created column Salary range:

# %%
salary_range=pd.cut(df['Income'], bins=[0, 44000, 51000, 59000,110000], include_lowest=True, labels=['low', 'mid', 'high', 'very high'])

# %%
df['salary_range']=salary_range
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles salary_range
# 0      112          low
# 1       75          low
# ...

# %%
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(15, 6))
sns.countplot(data=df, x='Product', hue="salary_range",edgecolor="0.15")

axs.set_title("Product Vs Salary Range", pad=10, fontsize=14)

plt.show()

# %% [markdown]
# Insights:
#
#     The income has been categorized in low, mid, high, and very high to further dig the behaviour of customers buying the products. There are customers with high and very high range income are also buying KP281.
#
# Recommendation:
#
#     They can be targeted to get them buy higher end products by educating and highlighting the features of higher end product. Also, customers with low and mid range income has bought KP481 and KP781 products which suggests certain segment of customers are interested to spend more for even if they have lower income. Some discount offer can be given to such segment of customers and and that can increase sale of higher end products.

# %%
#Some more bivariate analysis:

attributes = ['Education', 'Usage', 'Miles']
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(18, 5))
fig.subplots_adjust(top=1.2)
count = 0
for j in range(3):
    sns.boxplot(data=df, x='Product', y=attributes[count], ax=axs[j])
    axs[j].set_title(f"Product vs {attributes[count]}", pad=12, fontsize=13)
    count += 1

# %% [markdown]
# Insights:
#
#     1. More educated customers are more likely to buy KP781.
#     2. Customers with high usage likely to buy KP781.
#     3. Customers are likely to run more miles are going to buy higher range product.

# %%
Multivariate Analysis:

# %%
attributes = ['Income', 'Education', 'Age', 'Fitness', 'Usage', 'Miles']
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(18, 12))
fig.subplots_adjust(top=1.3)
count = 0
for i in range(3):
    for j in range(2):
        sns.boxplot(data=df, x='Gender', y=attributes[count], hue='Product', ax=axs[i,j])
        axs[i,j].set_title(f"Product vs {attributes[count]}", fontsize=13)
        count += 1

# %% [markdown]
# Insights:
#
#     1.There is not much difference in buying pattern considering if they have similar income.For females we have few outliers for KP481 product, but for males we don't see any outliers.
#     2.Higher education does seem to affect the buying behaviour. For both males and females with higher education has bought KP781.
#     3. Aged females seems to be less likely to buy the products. And in case of KP781 the chances of aged female using the product is even lesser.
#     4. Fit people are more likely to buy KP781 for both males and females.
#     5. Both females and males who are going to use it more often are more likely to buy KP781. But, there is a outlier for females with higher usage going for KP281; it means females who are going to use it less they are only going for KP281, KP481.
#     6. For miles also pattern is similar for males and females. But, there are few outliers for females where with higher miles going for KP481; it means females who are expected to run more only they are going to use KP781.
#
# Recommendations:
#
#     1. Aerofit can target such outlier female customers for KP481 to buy KP781.
#     2. Aerofit can think of targeting both aged males and females to promote their product. And, if the higher end product is can benefit better to old age people they can think of increase the sales of the higher end product by bringing awareness.
#     3. Since customers with higher usage and fitness are going to buy the KP781, we can somehow think of the ways by which customers resolved to spend more time for fitness that will automatically increase the enthusiasm of the customers going for higher end products.
#     4. Also we can notice significant gap between average usage and miles for KP481 and KP781. Aerofit can think of launching a new product in between the range of KP481 and KP781 that can attract medium and higher medium range customers to switch to litle higher end product.

# %%
attributes = ['Income', 'Education', 'Age', 'Fitness', 'Usage', 'Miles']
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(18, 12))
fig.subplots_adjust(top=1.3)
count = 0
for i in range(3):
    for j in range(2):
        sns.boxplot(data=df, x='MaritalStatus', y=attributes[count], hue='Product', ax=axs[i,j])
        axs[i,j].set_title(f"Product vs {attributes[count]}", fontsize=13)
        count += 1

# %% [markdown]
# Insights and Recommendations:
#
#     1. Partnered customers who has bought the products has higher income than customers with marital staus as single.
#     2. There is a significant gap in the income of the partnered customer buying KP481 and KP781 product. So, either Aerofit can think of launching a new product in between KP481 and KP781 or partnered customers can be given some discount offer on KP781 product.
#     3. Single customers with quite less median salary than that of partnered customers has bought the KP781 products.But, there is not much difference in the income among single and partnered customers buying the KP281 and KP481 products.This suggests if single is earning on a little higher side, there is more chances of them going for KP781 product in comparison to partnered customers.
#     4. For eductaion the pattern is similar for both males and females. With more education they are going to buy higher end product.
#     5. Median age buying the product is higher for partnered than single which seems to be obvious as people with partnered status are going to be aged more than the single ones.
#     6. For fitness the trend is similar for both single and partnered. Still, we can see for partnered fitness level 3 is outlier for product KP781 that means partnered with only higher fitness level are more likely to buy KP781 whereas for singles we have customers going for KP781 even with average fitness level.
#     7. For usage both single and partnered going to buy higher end product with higher usage. But, here also we see partnered only with usage higher than equal to 4 are going to buy KP781 whereas single with average usage have the chances to buy KP781. Aerofit can think of coming up with fitness awareness program for partnered customers.
#     8. For miles also we see that both single and partnered going to buy higher end product with higher miles. But, here also we see more outliers for KP281 and KP481 for partnered that shows some conservativeness in partnered buying pattern. Even with high expectation of miles few partnered customers are buying lower end product.

# %% [markdown]
# Correlation among different factors:

# %%
sns.heatmap(df.corr(), annot = True, cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Insights:
#
#     There are few attributes which are correlated.
#     More fit customer is likely to run more miles.
#     More education results in more income.
#     Age and fitness are also correlated.
#     More fit are likely to have more usage of the product.

# %% [markdown]
# Computing Marginal, conditional Probabilities:

# %%
pd.crosstab(index=df["Gender"],columns=df["Product"],margins=True)
# Out:
# Product  KP281  KP481  KP781  All
# Gender
# Female      40     29      7   76
# Male        40     31     33  104
# All         80     60     40  180

# %%
pd.crosstab(index=df["Gender"],columns=df["Product"],margins=True,normalize=True)
# Out:
# Product     KP281     KP481     KP781       All
# Gender
# Female   0.222222  0.161111  0.038889  0.422222
# Male     0.222222  0.172222  0.183333  0.577778
# All      0.444444  0.333333  0.222222  1.000000

# %%
pd.crosstab(index=df["Gender"],columns=df["Product"],margins=True,normalize="columns")
# Out:
# Product  KP281     KP481  KP781       All
# Gender
# Female     0.5  0.483333  0.175  0.422222
# Male       0.5  0.516667  0.825  0.577778

# %%
pd.crosstab(index=df["Gender"],columns=df["Product"],margins=True,normalize="index")
# Out:
# Product     KP281     KP481     KP781
# Gender
# Female   0.526316  0.381579  0.092105
# Male     0.384615  0.298077  0.317308
# All      0.444444  0.333333  0.222222

# %%
pd.crosstab(index=df["MaritalStatus"],columns=df["Product"],margins=True)
# Out:
# Product        KP281  KP481  KP781  All
# MaritalStatus
# Partnered         48     36     23  107
# Single            32     24     17   73
# All               80     60     40  180

# %%
pd.crosstab(index=df["MaritalStatus"],columns=df["Product"],margins=True,normalize=True)
# Out:
# Product           KP281     KP481     KP781       All
# MaritalStatus
# Partnered      0.266667  0.200000  0.127778  0.594444
# Single         0.177778  0.133333  0.094444  0.405556
# All            0.444444  0.333333  0.222222  1.000000

# %%
pd.crosstab(index=df["MaritalStatus"],columns=df["Product"],margins=True,normalize="columns")
# Out:
# Product        KP281  KP481  KP781       All
# MaritalStatus
# Partnered        0.6    0.6  0.575  0.594444
# Single           0.4    0.4  0.425  0.405556

# %%
pd.crosstab(index=df["MaritalStatus"],columns=df["Product"],margins=True,normalize="index")
# Out:
# Product           KP281     KP481     KP781
# MaritalStatus
# Partnered      0.448598  0.336449  0.214953
# Single         0.438356  0.328767  0.232877
# All            0.444444  0.333333  0.222222

# %%
pd.crosstab(index=df["salary_range"],columns=df["Product"],margins=True)
# Out:
# Product       KP281  KP481  KP781  All
# salary_range
# low              30     15      0   45
# mid              20     20      5   45
# high             23     16      6   45
# very high         7      9     29   45
# All              80     60     40  180

# %%
pd.crosstab(index=df["salary_range"],columns=df["Product"],margins=True,normalize=True)
# Out:
# Product          KP281     KP481     KP781   All
# salary_range
# low           0.166667  0.083333  0.000000  0.25
# mid           0.111111  0.111111  0.027778  0.25
# high          0.127778  0.088889  0.033333  0.25
# very high     0.038889  0.050000  0.161111  0.25
# All           0.444444  0.333333  0.222222  1.00

# %%
pd.crosstab(index=df["salary_range"],columns=df["Product"],margins=True,normalize="columns")
# Out:
# Product        KP281     KP481  KP781   All
# salary_range
# low           0.3750  0.250000  0.000  0.25
# mid           0.2500  0.333333  0.125  0.25
# high          0.2875  0.266667  0.150  0.25
# very high     0.0875  0.150000  0.725  0.25

# %%
pd.crosstab(index=df["salary_range"],columns=df["Product"],margins=True,normalize="index")
# Out:
# Product          KP281     KP481     KP781
# salary_range
# low           0.666667  0.333333  0.000000
# mid           0.444444  0.444444  0.111111
# high          0.511111  0.355556  0.133333
# very high     0.155556  0.200000  0.644444
# All           0.444444  0.333333  0.222222

# %% [markdown]
# Insights:
#
# Product:
#
#     44.44% of the customers have purchased KP2821 product.
#     33.33% of the customers have purchased KP481 product.
#     22.22% of the customers have purchased KP781 product.
#
# Gender:
#
#     57.78% of the customers are Male.
#     42.22% of the customers are female.
#
# MaritalStatus
#
#     59.44% of the customers are Partnered.
#     40.56% of the customers are single.
#
# Salary range:
#     25% of the customers are low income range.
#     25% of the customers are mid income range.
#     25% of the customers are high income range.
#     25% of the customers are very high income range.
#
# Conditional probabilities:
#
#     Gender:
#
#     P(KP781/Male): 0.32
#     P(KP481/Male): 0.30
#     P(KP281/Male): 0.38
#
#     P(KP781/Female): 0.09
#     P(KP481/Female): 0.38
#     P(KP281/Female): 0.53
#
#
#     MaritalStatus:
#
#     P(KP781/Single): 0.23
#     P(KP481/Single): 0.33
#     P(KP281/Single): 0.44
#
#     P(KP781/Partnered): 0.21
#     P(KP481/Partnered): 0.34
#     P(KP281/Partnered): 0.45
#
#
#     Salary range:
#
#     P(KP781/low): 0.00
#     P(KP481/low): 0.33
#     P(KP281/low): 0.67
#
#     P(KP781/mid): 0.11
#     P(KP481/mid): 0.44
#     P(KP281/mid): 0.44
#
#     P(KP781/high): 0.13
#     P(KP481/high): 0.36
#     P(KP281/high): 0.51
#
#     P(KP781/very high): 0.64
#     P(KP481/very high): 0.20
#     P(KP281/very high): 0.15

# %% [markdown]
# Insights and Recommendations:
#
#     1. We can see female buying KP781 is very low compared to males. Aerofit can organize female oriented fitness program to reach more female customers.
#     2. Even the difference between females buying KP481 is relatively low in comparison to buying KP281. So, there is a need to think to make females more interested in buying the product.
#     3. For males the buying pattern almost equally distributed for all three categories of products.
#     4. The data is similar basis marital status. Still, partnered customers should be more likely to buy the higher end product provided there can be two earning members, but we see single customers probability of buying higher end product is slightly higher than the partnered ones. Aerofit can target partnered customers to extend the buying of higher end product.
#     5. As expected income is a major factor in deciding customer going for a certain product. But, we still there are customers from medium range income 11% of them going for KP781. This is a good sign and Aerofit can encash this oppurtunity in finding who are these customers and try to advertise their product in those areas or companies they work for to further expand their business. Also, they can come up with several discount offers to boost the sales for such promising customers.
#     6. On the contrary, we have quite a lot high earning customers(51%) going for KP281. Also, customers with very high income(15%) are buying KP281. There is a need for Aerofit to understand the inhibition of these customers in spending more for fitness product inspite of them having high income.
